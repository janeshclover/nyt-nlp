# %% [markdown]
# # NYT API Data Collection: June

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting June data 1981-2021:*

# %%
r621 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text621 = r621.text
json.loads(text621)
df621 = pd.json_normalize(r621.json()['response']['docs'])

r620 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text620 = r620.text
json.loads(text620)
df620 = pd.json_normalize(r620.json()['response']['docs'])

r619 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text619 = r619.text
json.loads(text619)
df619 = pd.json_normalize(r619.json()['response']['docs'])

r618 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text618 = r618.text
json.loads(text618)
df618 = pd.json_normalize(r618.json()['response']['docs'])

r617 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text617 = r617.text
json.loads(text617)
df617 = pd.json_normalize(r617.json()['response']['docs'])

r616 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text616 = r616.text
json.loads(text616)
df616 = pd.json_normalize(r616.json()['response']['docs'])

r615 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text615 = r615.text
json.loads(text615)
df615 = pd.json_normalize(r615.json()['response']['docs'])

r614 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text614 = r614.text
json.loads(text614)
df614 = pd.json_normalize(r614.json()['response']['docs'])

r613 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text613 = r613.text
json.loads(text613)
df613 = pd.json_normalize(r613.json()['response']['docs'])

r612 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text612 = r612.text
json.loads(text612)
df612 = pd.json_normalize(r612.json()['response']['docs'])

r611 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text611 = r611.text
json.loads(text611)
df611 = pd.json_normalize(r611.json()['response']['docs'])

r610 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text610 = r610.text
json.loads(text610)
df610 = pd.json_normalize(r610.json()['response']['docs'])

r609 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text609 = r609.text
json.loads(text609)
df609 = pd.json_normalize(r609.json()['response']['docs'])

r608 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text608 = r608.text
json.loads(text608)
df608 = pd.json_normalize(r608.json()['response']['docs'])

r607 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text607 = r607.text
json.loads(text607)
df607 = pd.json_normalize(r607.json()['response']['docs'])

r606 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text606 = r606.text
json.loads(text606)
df606 = pd.json_normalize(r606.json()['response']['docs'])

r605 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text605 = r605.text
json.loads(text605)
df605 = pd.json_normalize(r605.json()['response']['docs'])

r604 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text604 = r604.text
json.loads(text604)
df604 = pd.json_normalize(r604.json()['response']['docs'])

r603 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text603 = r603.text
json.loads(text603)
df603 = pd.json_normalize(r603.json()['response']['docs'])

r602 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text602 = r602.text
json.loads(text602)
df602 = pd.json_normalize(r602.json()['response']['docs'])

r601 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text601 = r601.text
json.loads(text601)
df601 = pd.json_normalize(r601.json()['response']['docs'])

r600 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text600 = r600.text
json.loads(text600)
df600 = pd.json_normalize(r600.json()['response']['docs'])

r699 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text699 = r699.text
json.loads(text699)
df699 = pd.json_normalize(r699.json()['response']['docs'])

r698 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text698 = r698.text
json.loads(text698)
df698 = pd.json_normalize(r698.json()['response']['docs'])

r697 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text697 = r697.text
json.loads(text697)
df697 = pd.json_normalize(r697.json()['response']['docs'])

r696 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text696 = r696.text
json.loads(text696)
df696 = pd.json_normalize(r696.json()['response']['docs'])

r695 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text695 = r695.text
json.loads(text695)
df695 = pd.json_normalize(r695.json()['response']['docs'])

r694 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text694 = r694.text
json.loads(text694)
df694 = pd.json_normalize(r694.json()['response']['docs'])

r693 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text693 = r693.text
json.loads(text693)
df693 = pd.json_normalize(r693.json()['response']['docs'])

r692 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text692 = r692.text
json.loads(text692)
df692 = pd.json_normalize(r692.json()['response']['docs'])

r691 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text691 = r691.text
json.loads(text691)
df691 = pd.json_normalize(r691.json()['response']['docs'])

r690 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text690 = r690.text
json.loads(text690)
df690 = pd.json_normalize(r690.json()['response']['docs'])

r689 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text689 = r689.text
json.loads(text689)
df689 = pd.json_normalize(r689.json()['response']['docs'])

r688 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text688 = r688.text
json.loads(text688)
df688 = pd.json_normalize(r688.json()['response']['docs'])

r687 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text687 = r687.text
json.loads(text687)
df687 = pd.json_normalize(r687.json()['response']['docs'])

r686 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text686 = r686.text
json.loads(text686)
df686 = pd.json_normalize(r686.json()['response']['docs'])

r685 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text685 = r685.text
json.loads(text685)
df685 = pd.json_normalize(r685.json()['response']['docs'])

r684 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text684 = r684.text
json.loads(text684)
df684 = pd.json_normalize(r684.json()['response']['docs'])

r683 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text683 = r683.text
json.loads(text683)
df683 = pd.json_normalize(r683.json()['response']['docs'])

r682 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text682 = r682.text
json.loads(text682)
df682 = pd.json_normalize(r682.json()['response']['docs'])

r681 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/6.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text681 = r681.text
json.loads(text681)
df681 = pd.json_normalize(r681.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
jun_concat = pd.concat([df621, df620, df619, df618, df617, df616, df615, df614, df613, df612, df611, 
                    df610, df609, df608, df607, df606, df605, df604, df603, df602, df601, 
                    df600, df699, df698, df697, df696, df695, df694, df693, df692, df691, 
                    df690, df689, df688, df687, df686, df685, df684, df683, df682, df681])

# %%
jun_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323388 entries, 0 to 8163
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 323388 non-null  object
#  1   web_url                  323388 non-null  object
#  2   snippet                  323388 non-null  object
#  3   lead_paragraph           323388 non-null  object
#  4   source                   323388 non-null  object
#  5   multimedia               323388 non-null  object
#  6   keywords                 323388 non-null  object
#  7   pub_date                 323388 non-null  object
#  8   document_type            323388 non-null  object
#  9   news_desk                323388 non-null  object
#  10  section_name             323388 non-null  object
#  11  subsection_name          50841 non-null   object
#  12  type_of_material         323388 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
jun_df = jun_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
jun_df
# Out:
#                                           headline.main  \
# 0     Glum to Gleeful, Israeli Media React to Possib...
# 1     Serena Williams Wins in the First Round at the...
# 2     Illinois Lawmakers Bar Police From Using Decep...
# 3                     With the Candlestick in the Study
# 4     How Do Animals Safely Cross a Highway? Take a ...
# ...                                                 ...
# 8159                        PINELAND PLAN FACING A TEST
# 8160                                        No Headline
# 8161       Market Place; Penn Central's Rail Settlement
# 8162  GREAT NATIONAL CORP reports earnings for Qtr t...
# 8163                                 REAGAN'S REAL TEST
#
#                       pub_date        section_name  word_count  \
# 0     2021-06-01T00:06:19+0000               World         984
# 1     2021-06-01T00:48:42+0000              Sports         722
# 2     2021-06-01T01:32:28+0000                U.S.         880
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
jun_df.to_csv('June 1981-2021.csv', index=False)
