# %% [markdown]
# # NYT API Data Collection: July

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting July data 1981-2021:*

# %%
r721 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text721 = r721.text
json.loads(text721)
df721 = pd.json_normalize(r721.json()['response']['docs'])

r720 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text720 = r720.text
json.loads(text720)
df720 = pd.json_normalize(r720.json()['response']['docs'])

r719 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text719 = r719.text
json.loads(text719)
df719 = pd.json_normalize(r719.json()['response']['docs'])

r718 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text718 = r718.text
json.loads(text718)
df718 = pd.json_normalize(r718.json()['response']['docs'])

r717 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text717 = r717.text
json.loads(text717)
df717 = pd.json_normalize(r717.json()['response']['docs'])

r716 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text716 = r716.text
json.loads(text716)
df716 = pd.json_normalize(r716.json()['response']['docs'])

r715 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text715 = r715.text
json.loads(text715)
df715 = pd.json_normalize(r715.json()['response']['docs'])

r714 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text714 = r714.text
json.loads(text714)
df714 = pd.json_normalize(r714.json()['response']['docs'])

r713 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text713 = r713.text
json.loads(text713)
df713 = pd.json_normalize(r713.json()['response']['docs'])

r712 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text712 = r712.text
json.loads(text712)
df712 = pd.json_normalize(r712.json()['response']['docs'])

r711 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text711 = r711.text
json.loads(text711)
df711 = pd.json_normalize(r711.json()['response']['docs'])

r710 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text710 = r710.text
json.loads(text710)
df710 = pd.json_normalize(r710.json()['response']['docs'])

r709 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text709 = r709.text
json.loads(text709)
df709 = pd.json_normalize(r709.json()['response']['docs'])

r708 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text708 = r708.text
json.loads(text708)
df708 = pd.json_normalize(r708.json()['response']['docs'])

r707 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text707 = r707.text
json.loads(text707)
df707 = pd.json_normalize(r707.json()['response']['docs'])

r706 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text706 = r706.text
json.loads(text706)
df706 = pd.json_normalize(r706.json()['response']['docs'])

r705 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text705 = r705.text
json.loads(text705)
df705 = pd.json_normalize(r705.json()['response']['docs'])

r704 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text704 = r704.text
json.loads(text704)
df704 = pd.json_normalize(r704.json()['response']['docs'])

r703 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text703 = r703.text
json.loads(text703)
df703 = pd.json_normalize(r703.json()['response']['docs'])

r702 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text702 = r702.text
json.loads(text702)
df702 = pd.json_normalize(r702.json()['response']['docs'])

r701 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text701 = r701.text
json.loads(text701)
df701 = pd.json_normalize(r701.json()['response']['docs'])

r700 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text700 = r700.text
json.loads(text700)
df700 = pd.json_normalize(r700.json()['response']['docs'])

r799 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text799 = r799.text
json.loads(text799)
df799 = pd.json_normalize(r799.json()['response']['docs'])

r798 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text798 = r798.text
json.loads(text798)
df798 = pd.json_normalize(r798.json()['response']['docs'])

r797 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text797 = r797.text
json.loads(text797)
df797 = pd.json_normalize(r797.json()['response']['docs'])

r796 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text796 = r796.text
json.loads(text796)
df796 = pd.json_normalize(r796.json()['response']['docs'])

r795 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text795 = r795.text
json.loads(text795)
df795 = pd.json_normalize(r795.json()['response']['docs'])

r794 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text794 = r794.text
json.loads(text794)
df794 = pd.json_normalize(r794.json()['response']['docs'])

r793 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text793 = r793.text
json.loads(text793)
df793 = pd.json_normalize(r793.json()['response']['docs'])

r792 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text792 = r792.text
json.loads(text792)
df792 = pd.json_normalize(r792.json()['response']['docs'])

r791 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text791 = r791.text
json.loads(text791)
df791 = pd.json_normalize(r791.json()['response']['docs'])

r790 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text790 = r790.text
json.loads(text790)
df790 = pd.json_normalize(r790.json()['response']['docs'])

r789 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text789 = r789.text
json.loads(text789)
df789 = pd.json_normalize(r789.json()['response']['docs'])

r788 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text788 = r788.text
json.loads(text788)
df788 = pd.json_normalize(r788.json()['response']['docs'])

r787 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text787 = r787.text
json.loads(text787)
df787 = pd.json_normalize(r787.json()['response']['docs'])

r786 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text786 = r786.text
json.loads(text786)
df786 = pd.json_normalize(r786.json()['response']['docs'])

r785 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text785 = r785.text
json.loads(text785)
df785 = pd.json_normalize(r785.json()['response']['docs'])

r784 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text784 = r784.text
json.loads(text784)
df784 = pd.json_normalize(r784.json()['response']['docs'])

r783 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text783 = r783.text
json.loads(text783)
df783 = pd.json_normalize(r783.json()['response']['docs'])

r782 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text782 = r782.text
json.loads(text782)
df782 = pd.json_normalize(r782.json()['response']['docs'])

r781 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/7.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text781 = r781.text
json.loads(text781)
df781 = pd.json_normalize(r781.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
jul_concat = pd.concat([df721, df720, df719, df718, df717, df716, df715, df714, df713, df712, df711, 
                    df710, df709, df708, df707, df706, df705, df704, df703, df702, df701, 
                    df700, df799, df798, df797, df796, df795, df794, df793, df792, df791, 
                    df790, df789, df788, df787, df786, df785, df784, df783, df782, df781])

# %%
jul_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325079 entries, 0 to 7551
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 325079 non-null  object
#  1   web_url                  325079 non-null  object
#  2   snippet                  325079 non-null  object
#  3   lead_paragraph           325079 non-null  object
#  4   print_section            268809 non-null  object
#  5   print_page               268730 non-null  object
#  6   source                   325079 non-null  object
#  7   multimedia               325079 non-null  object
#  8   keywords                 325079 non-null  object
#  9   pub_date                 325079 non-null  object
#  10  document_type            325079 non-null  object
#  11  news_desk                325079 non-null  object
#  12  section_name             325079 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
jul_df = jul_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
jul_df
# Out:
#                                           headline.main  \
# 0         From Google, on Its Advertising Tech Business
# 1     The N.B.A. Champion May Be the Last Team Standing
# 2     A poll reveals another U.S. vaccine divide, th...
# 3     Judge Blocks Florida Law Regulating Social Med...
# 4     James Franco Agrees to Pay $2.2 Million to Set...
# ...                                                 ...
# 7547                News Summary; FRIDAY, JULY 31, 1981
# 7548                                    A Little Secret
# 7549                                 Books Of The Times
# 7550  WHITE HOUSE ASKS A LAW TO BAR JOBS FOR ILLEGAL...
# 7551                               Indonesia in Katonah
#
#                       pub_date section_name  word_count  \
# 0     2021-07-01T00:05:28+0000      Opinion         276
# 1     2021-07-01T00:06:11+0000       Sports        1508
# 2     2021-07-01T00:09:09+0000         U.S.         420
# 3     2021-07-01T01:35:32+0000   Technology         262
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
jul_df.to_csv('July 1981-2021.csv', index=False)
