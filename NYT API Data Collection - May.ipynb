# %% [markdown]
# # NYT API Data Collection: May

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting May data 1981-2021:*

# %%
r521 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text521 = r521.text
json.loads(text521)
df521 = pd.json_normalize(r521.json()['response']['docs'])

r520 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text520 = r520.text
json.loads(text520)
df520 = pd.json_normalize(r520.json()['response']['docs'])

r519 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text519 = r519.text
json.loads(text519)
df519 = pd.json_normalize(r519.json()['response']['docs'])

r518 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text518 = r518.text
json.loads(text518)
df518 = pd.json_normalize(r518.json()['response']['docs'])

r517 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text517 = r517.text
json.loads(text517)
df517 = pd.json_normalize(r517.json()['response']['docs'])

r516 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text516 = r516.text
json.loads(text516)
df516 = pd.json_normalize(r516.json()['response']['docs'])

r515 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text515 = r515.text
json.loads(text515)
df515 = pd.json_normalize(r515.json()['response']['docs'])

r514 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text514 = r514.text
json.loads(text514)
df514 = pd.json_normalize(r514.json()['response']['docs'])

r513 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text513 = r513.text
json.loads(text513)
df513 = pd.json_normalize(r513.json()['response']['docs'])

r512 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text512 = r512.text
json.loads(text512)
df512 = pd.json_normalize(r512.json()['response']['docs'])

r511 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text511 = r511.text
json.loads(text511)
df511 = pd.json_normalize(r511.json()['response']['docs'])

r510 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text510 = r510.text
json.loads(text510)
df510 = pd.json_normalize(r510.json()['response']['docs'])

r509 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text509 = r509.text
json.loads(text509)
df509 = pd.json_normalize(r509.json()['response']['docs'])

r508 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text508 = r508.text
json.loads(text508)
df508 = pd.json_normalize(r508.json()['response']['docs'])

r507 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text507 = r507.text
json.loads(text507)
df507 = pd.json_normalize(r507.json()['response']['docs'])

r506 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text506 = r506.text
json.loads(text506)
df506 = pd.json_normalize(r506.json()['response']['docs'])

r505 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text505 = r505.text
json.loads(text505)
df505 = pd.json_normalize(r505.json()['response']['docs'])

r504 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text504 = r504.text
json.loads(text504)
df504 = pd.json_normalize(r504.json()['response']['docs'])

r503 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text503 = r503.text
json.loads(text503)
df503 = pd.json_normalize(r503.json()['response']['docs'])

r502 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text502 = r502.text
json.loads(text502)
df502 = pd.json_normalize(r502.json()['response']['docs'])

r501 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text501 = r501.text
json.loads(text501)
df501 = pd.json_normalize(r501.json()['response']['docs'])

r500 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text500 = r500.text
json.loads(text500)
df500 = pd.json_normalize(r500.json()['response']['docs'])

r599 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text599 = r599.text
json.loads(text599)
df599 = pd.json_normalize(r599.json()['response']['docs'])

r598 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text598 = r598.text
json.loads(text598)
df598 = pd.json_normalize(r598.json()['response']['docs'])

r597 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text597 = r597.text
json.loads(text597)
df597 = pd.json_normalize(r597.json()['response']['docs'])

r596 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text596 = r596.text
json.loads(text596)
df596 = pd.json_normalize(r596.json()['response']['docs'])

r595 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text595 = r595.text
json.loads(text595)
df595 = pd.json_normalize(r595.json()['response']['docs'])

r594 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text594 = r594.text
json.loads(text594)
df594 = pd.json_normalize(r594.json()['response']['docs'])

r593 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text593 = r593.text
json.loads(text593)
df593 = pd.json_normalize(r593.json()['response']['docs'])

r592 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text592 = r592.text
json.loads(text592)
df592 = pd.json_normalize(r592.json()['response']['docs'])

r591 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text591 = r591.text
json.loads(text591)
df591 = pd.json_normalize(r591.json()['response']['docs'])

r590 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text590 = r590.text
json.loads(text590)
df590 = pd.json_normalize(r590.json()['response']['docs'])

r589 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text589 = r589.text
json.loads(text589)
df589 = pd.json_normalize(r589.json()['response']['docs'])

r588 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text588 = r588.text
json.loads(text588)
df588 = pd.json_normalize(r588.json()['response']['docs'])

r587 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text587 = r587.text
json.loads(text587)
df587 = pd.json_normalize(r587.json()['response']['docs'])

r586 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text586 = r586.text
json.loads(text586)
df586 = pd.json_normalize(r586.json()['response']['docs'])

r585 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text585 = r585.text
json.loads(text585)
df585 = pd.json_normalize(r585.json()['response']['docs'])

r584 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text584 = r584.text
json.loads(text584)
df584 = pd.json_normalize(r584.json()['response']['docs'])

r583 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text583 = r583.text
json.loads(text583)
df583 = pd.json_normalize(r583.json()['response']['docs'])

r582 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text582 = r582.text
json.loads(text582)
df582 = pd.json_normalize(r582.json()['response']['docs'])

r581 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/5.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text581 = r581.text
json.loads(text581)
df581 = pd.json_normalize(r581.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
may_concat = pd.concat([df521, df520, df519, df518, df517, df516, df515, df514, df513, df512, df511, 
                    df510, df509, df508, df507, df506, df505, df504, df503, df502, df501, 
                    df500, df599, df598, df597, df596, df595, df594, df593, df592, df591, 
                    df590, df589, df588, df587, df586, df585, df584, df583, df582, df581])

# %%
may_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341386 entries, 0 to 8681
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 341386 non-null  object
#  1   web_url                  341386 non-null  object
#  2   snippet                  341386 non-null  object
#  3   lead_paragraph           341386 non-null  object
#  4   source                   341386 non-null  object
#  5   multimedia               341386 non-null  object
#  6   keywords                 341386 non-null  object
#  7   pub_date                 341386 non-null  object
#  8   document_type            341386 non-null  object
#  9   news_desk                341386 non-null  object
#  10  section_name             341386 non-null  object
#  11  type_of_material         341386 non-null  object
#  12  _id                      341386 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
may_df = may_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
may_df
# Out:
#                                           headline.main  \
# 0     Three Colorado Officers Resign After Arrest of...
# 1     Manchin says he won’t support a D.C. statehood...
# 2     MoMA Blocks Protesters Who Planned to Demonstr...
# 3     Eli Broad, Who Helped Reshape Los Angeles, Die...
# 4                              Corrections: May 1, 2021
# ...                                                 ...
# 8677  Gardening;\nIT'S TIME FOR SPRAYING AND FERTILI...
# 8678                                Personally Speaking
# 8679                       Scott Outkicks Maree in Mile
# 8680  Letters; KEMP-ROTH SAVINGS EFFECT MAY BE ILLUSORY
# 8681                       Food; A SEAFARER'S SPECIALTY
#
#                       pub_date section_name  word_count  \
# 0     2021-05-01T00:05:13+0000         U.S.         550
# 1     2021-05-01T00:24:56+0000         U.S.         318
# 2     2021-05-01T00:31:50+0000         Arts         509
# 3     2021-05-01T00:44:01+0000         U.S.        1538
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
may_df.to_csv('May 1981-2021.csv', index=False)
