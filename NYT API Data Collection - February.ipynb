# %% [markdown]
# # NYT API Data Collection: February

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting February data 1981-2021:*

# %%
r221 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text221 = r221.text
json.loads(text221)
df221 = pd.json_normalize(r221.json()['response']['docs'])

r220 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text220 = r220.text
json.loads(text220)
df220 = pd.json_normalize(r220.json()['response']['docs'])

r219 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text219 = r219.text
json.loads(text219)
df219 = pd.json_normalize(r219.json()['response']['docs'])

r218 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text218 = r218.text
json.loads(text218)
df218 = pd.json_normalize(r218.json()['response']['docs'])

r217 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text217 = r217.text
json.loads(text217)
df217 = pd.json_normalize(r217.json()['response']['docs'])

r216 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text216 = r216.text
json.loads(text216)
df216 = pd.json_normalize(r216.json()['response']['docs'])

r215 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text215 = r215.text
json.loads(text215)
df215 = pd.json_normalize(r215.json()['response']['docs'])

r214 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text214 = r214.text
json.loads(text214)
df214 = pd.json_normalize(r214.json()['response']['docs'])

r213 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text213 = r213.text
json.loads(text213)
df213 = pd.json_normalize(r213.json()['response']['docs'])

r212 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text212 = r212.text
json.loads(text212)
df212 = pd.json_normalize(r212.json()['response']['docs'])

r211 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text211 = r211.text
json.loads(text211)
df211 = pd.json_normalize(r211.json()['response']['docs'])

r210 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text210 = r210.text
json.loads(text210)
df210 = pd.json_normalize(r210.json()['response']['docs'])

r209 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text209 = r209.text
json.loads(text209)
df209 = pd.json_normalize(r209.json()['response']['docs'])

r208 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text208 = r208.text
json.loads(text208)
df208 = pd.json_normalize(r208.json()['response']['docs'])

r207 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text207 = r207.text
json.loads(text207)
df207 = pd.json_normalize(r207.json()['response']['docs'])

r206 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text206 = r206.text
json.loads(text206)
df206 = pd.json_normalize(r206.json()['response']['docs'])

r205 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text205 = r205.text
json.loads(text205)
df205 = pd.json_normalize(r205.json()['response']['docs'])

r204 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text204 = r204.text
json.loads(text204)
df204 = pd.json_normalize(r204.json()['response']['docs'])

r203 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text203 = r203.text
json.loads(text203)
df203 = pd.json_normalize(r203.json()['response']['docs'])

r202 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text202 = r202.text
json.loads(text202)
df202 = pd.json_normalize(r202.json()['response']['docs'])

r201 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text201 = r201.text
json.loads(text201)
df201 = pd.json_normalize(r201.json()['response']['docs'])

r200 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text200 = r200.text
json.loads(text200)
df200 = pd.json_normalize(r200.json()['response']['docs'])

r299 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text299 = r299.text
json.loads(text299)
df299 = pd.json_normalize(r299.json()['response']['docs'])

r298 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text298 = r298.text
json.loads(text298)
df298 = pd.json_normalize(r298.json()['response']['docs'])

r297 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text297 = r297.text
json.loads(text297)
df297 = pd.json_normalize(r297.json()['response']['docs'])

r296 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text296 = r296.text
json.loads(text296)
df296 = pd.json_normalize(r296.json()['response']['docs'])

r295 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text295 = r295.text
json.loads(text295)
df295 = pd.json_normalize(r295.json()['response']['docs'])

r294 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text294 = r294.text
json.loads(text294)
df294 = pd.json_normalize(r294.json()['response']['docs'])

r293 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text293 = r293.text
json.loads(text293)
df293 = pd.json_normalize(r293.json()['response']['docs'])

r292 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text292 = r292.text
json.loads(text292)
df292 = pd.json_normalize(r292.json()['response']['docs'])

r291 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text291 = r291.text
json.loads(text291)
df291 = pd.json_normalize(r291.json()['response']['docs'])

r290 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text290 = r290.text
json.loads(text290)
df290 = pd.json_normalize(r290.json()['response']['docs'])

r289 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text289 = r289.text
json.loads(text289)
df289 = pd.json_normalize(r289.json()['response']['docs'])

r288 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text288 = r288.text
json.loads(text288)
df288 = pd.json_normalize(r288.json()['response']['docs'])

r287 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text287 = r287.text
json.loads(text287)
df287 = pd.json_normalize(r287.json()['response']['docs'])

r286 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text286 = r286.text
json.loads(text286)
df286 = pd.json_normalize(r286.json()['response']['docs'])

r285 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text285 = r285.text
json.loads(text285)
df285 = pd.json_normalize(r285.json()['response']['docs'])

r284 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text284 = r284.text
json.loads(text284)
df284 = pd.json_normalize(r284.json()['response']['docs'])

r283 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text283 = r283.text
json.loads(text283)
df283 = pd.json_normalize(r283.json()['response']['docs'])

r282 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text282 = r282.text
json.loads(text282)
df282 = pd.json_normalize(r282.json()['response']['docs'])

r281 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/2.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text281 = r281.text
json.loads(text281)
df281 = pd.json_normalize(r281.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
feb_concat = pd.concat([df221, df220, df219, df218, df217, df216, df215, df214, df213, df212, df211, 
                    df210, df209, df208, df207, df206, df205, df204, df203, df202, df201, 
                    df200, df299, df298, df297, df296, df295, df294, df293, df292, df291, 
                    df290, df289, df288, df287, df286, df285, df284, df283, df282, df281])

# %%
feb_concat.info()

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
feb_df = feb_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
feb_df
# Out:
#                                           headline.main  \
# 0     Effort to Include $15 Minimum Wage in Relief B...
# 1     Trump Names Two Members of Impeachment Defense...
# 2     Rochester Officers Suspended After Pepper-Spra...
# 3     Review: Seeking a Date but Finding Hypocrisy i...
# 4                              Survey Says: Never Tweet
# ...                                                 ...
# 6575                                            ANSWERS
# 6576              UNION HEAD ASSAILS INQUIRY ON RACKETS
# 6577                                         CORRECTION
# 6578    U.N. ATOM AGENCY LAUDS MOVES BY EGYPT AND LIBYA
# 6579  U.S. JUDGE DEFERS DECISION IN WILLIAMS-SONICS ...
#
#                       pub_date  section_name  word_count  \
# 0     2021-02-01T00:04:59+0000          U.S.        1344
# 1     2021-02-01T01:54:42+0000          U.S.         524
# 2     2021-02-01T01:57:23+0000      New York         792
# 3     2021-02-01T02:00:05+0000       Theater         744
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
feb_df.to_csv('February 1981-2021.csv', index=False)
