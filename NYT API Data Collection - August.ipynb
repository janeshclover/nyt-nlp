# %% [markdown]
# # NYT API Data Collection: August

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting August data 1981-2021:*

# %%
r821 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text821 = r821.text
json.loads(text821)
df821 = pd.json_normalize(r821.json()['response']['docs'])

r820 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text820 = r820.text
json.loads(text820)
df820 = pd.json_normalize(r820.json()['response']['docs'])

r819 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text819 = r819.text
json.loads(text819)
df819 = pd.json_normalize(r819.json()['response']['docs'])

r818 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text818 = r818.text
json.loads(text818)
df818 = pd.json_normalize(r818.json()['response']['docs'])

r817 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text817 = r817.text
json.loads(text817)
df817 = pd.json_normalize(r817.json()['response']['docs'])

r816 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text816 = r816.text
json.loads(text816)
df816 = pd.json_normalize(r816.json()['response']['docs'])

r815 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text815 = r815.text
json.loads(text815)
df815 = pd.json_normalize(r815.json()['response']['docs'])

r814 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text814 = r814.text
json.loads(text814)
df814 = pd.json_normalize(r814.json()['response']['docs'])

r813 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text813 = r813.text
json.loads(text813)
df813 = pd.json_normalize(r813.json()['response']['docs'])

r812 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text812 = r812.text
json.loads(text812)
df812 = pd.json_normalize(r812.json()['response']['docs'])

r811 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text811 = r811.text
json.loads(text811)
df811 = pd.json_normalize(r811.json()['response']['docs'])

r810 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text810 = r810.text
json.loads(text810)
df810 = pd.json_normalize(r810.json()['response']['docs'])

r809 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text809 = r809.text
json.loads(text809)
df809 = pd.json_normalize(r809.json()['response']['docs'])

r808 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text808 = r808.text
json.loads(text808)
df808 = pd.json_normalize(r808.json()['response']['docs'])

r807 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text807 = r807.text
json.loads(text807)
df807 = pd.json_normalize(r807.json()['response']['docs'])

r806 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text806 = r806.text
json.loads(text806)
df806 = pd.json_normalize(r806.json()['response']['docs'])

r805 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text805 = r805.text
json.loads(text805)
df805 = pd.json_normalize(r805.json()['response']['docs'])

r804 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text804 = r804.text
json.loads(text804)
df804 = pd.json_normalize(r804.json()['response']['docs'])

r803 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text803 = r803.text
json.loads(text803)
df803 = pd.json_normalize(r803.json()['response']['docs'])

r802 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text802 = r802.text
json.loads(text802)
df802 = pd.json_normalize(r802.json()['response']['docs'])

r801 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text801 = r801.text
json.loads(text801)
df801 = pd.json_normalize(r801.json()['response']['docs'])

r800 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text800 = r800.text
json.loads(text800)
df800 = pd.json_normalize(r800.json()['response']['docs'])

r899 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text899 = r899.text
json.loads(text899)
df899 = pd.json_normalize(r899.json()['response']['docs'])

r898 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text898 = r898.text
json.loads(text898)
df898 = pd.json_normalize(r898.json()['response']['docs'])

r897 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text897 = r897.text
json.loads(text897)
df897 = pd.json_normalize(r897.json()['response']['docs'])

r896 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text896 = r896.text
json.loads(text896)
df896 = pd.json_normalize(r896.json()['response']['docs'])

r895 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text895 = r895.text
json.loads(text895)
df895 = pd.json_normalize(r895.json()['response']['docs'])

r894 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text894 = r894.text
json.loads(text894)
df894 = pd.json_normalize(r894.json()['response']['docs'])

r893 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text893 = r893.text
json.loads(text893)
df893 = pd.json_normalize(r893.json()['response']['docs'])

r892 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text892 = r892.text
json.loads(text892)
df892 = pd.json_normalize(r892.json()['response']['docs'])

r891 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text891 = r891.text
json.loads(text891)
df891 = pd.json_normalize(r891.json()['response']['docs'])

r890 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text890 = r890.text
json.loads(text890)
df890 = pd.json_normalize(r890.json()['response']['docs'])

r889 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text889 = r889.text
json.loads(text889)
df889 = pd.json_normalize(r889.json()['response']['docs'])

r888 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text888 = r888.text
json.loads(text888)
df888 = pd.json_normalize(r888.json()['response']['docs'])

r887 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text887 = r887.text
json.loads(text887)
df887 = pd.json_normalize(r887.json()['response']['docs'])

r886 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text886 = r886.text
json.loads(text886)
df886 = pd.json_normalize(r886.json()['response']['docs'])

r885 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text885 = r885.text
json.loads(text885)
df885 = pd.json_normalize(r885.json()['response']['docs'])

r884 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text884 = r884.text
json.loads(text884)
df884 = pd.json_normalize(r884.json()['response']['docs'])

r883 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text883 = r883.text
json.loads(text883)
df883 = pd.json_normalize(r883.json()['response']['docs'])

r882 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text882 = r882.text
json.loads(text882)
df882 = pd.json_normalize(r882.json()['response']['docs'])

r881 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/8.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text881 = r881.text
json.loads(text881)
df881 = pd.json_normalize(r881.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
aug_concat = pd.concat([df821, df820, df819, df818, df817, df816, df815, df814, df813, df812, df811, 
                    df810, df809, df808, df807, df806, df805, df804, df803, df802, df801, 
                    df800, df899, df898, df897, df896, df895, df894, df893, df892, df891, 
                    df890, df889, df888, df887, df886, df885, df884, df883, df882, df881])

# %%
aug_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323831 entries, 0 to 7756
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 323831 non-null  object
#  1   web_url                  323831 non-null  object
#  2   snippet                  323831 non-null  object
#  3   lead_paragraph           323831 non-null  object
#  4   source                   323831 non-null  object
#  5   multimedia               323831 non-null  object
#  6   keywords                 323831 non-null  object
#  7   pub_date                 323831 non-null  object
#  8   document_type            323831 non-null  object
#  9   news_desk                323831 non-null  object
#  10  section_name             323831 non-null  object
#  11  type_of_material         323831 non-null  object
#  12  _id                      323831 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
aug_df = aug_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
aug_df
# Out:
#                                           headline.main  \
# 0     2 Dead in Random Shooting at ‘Purge’ Movie, Of...
# 1     In swimming’s finale, the U.S. men keep their ...
# 2     With seven medals at one Olympics, Emma McKeon...
# 3     Quotation of the Day: Who Are the Unvaccinated...
# 4     Gov. Greg Abbott bars mandates for vaccination...
# ...                                                 ...
# 7752                             RIGHTS: ASSERT OR LOSE
# 7753  LOOKING AHEAD, TOWN USES STUDENT FEES, NOT TAX...
# 7754  SEARCHERS SURPRISED BY SIZE OF HOLE IN DORIA W...
# 7755       CHILDREN'S VIDEO GAMES: WHO WINS (OR LOSES)?
# 7756                 'PERSONAL GROWTH' IN THE WORKPLACE
#
#                       pub_date   section_name  word_count  \
# 0     2021-08-01T01:02:44+0000           U.S.         425
# 1     2021-08-01T01:11:42+0000         Sports        1188
# 2     2021-08-01T02:26:22+0000         Sports         296
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
aug_df.to_csv('August 1981-2021.csv', index=False)
