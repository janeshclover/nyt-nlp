# %% [markdown]
# # NYT API Data Collection: April

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting April data 1981-2021:*

# %%
r421 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text421 = r421.text
json.loads(text421)
df421 = pd.json_normalize(r421.json()['response']['docs'])

r420 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text420 = r420.text
json.loads(text420)
df420 = pd.json_normalize(r420.json()['response']['docs'])

r419 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text419 = r419.text
json.loads(text419)
df419 = pd.json_normalize(r419.json()['response']['docs'])

r418 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text418 = r418.text
json.loads(text418)
df418 = pd.json_normalize(r418.json()['response']['docs'])

r417 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text417 = r417.text
json.loads(text417)
df417 = pd.json_normalize(r417.json()['response']['docs'])

r416 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text416 = r416.text
json.loads(text416)
df416 = pd.json_normalize(r416.json()['response']['docs'])

r415 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text415 = r415.text
json.loads(text415)
df415 = pd.json_normalize(r415.json()['response']['docs'])

r414 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text414 = r414.text
json.loads(text414)
df414 = pd.json_normalize(r414.json()['response']['docs'])

r413 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text413 = r413.text
json.loads(text413)
df413 = pd.json_normalize(r413.json()['response']['docs'])

r412 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text412 = r412.text
json.loads(text412)
df412 = pd.json_normalize(r412.json()['response']['docs'])

r411 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text411 = r411.text
json.loads(text411)
df411 = pd.json_normalize(r411.json()['response']['docs'])

r410 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text410 = r410.text
json.loads(text410)
df410 = pd.json_normalize(r410.json()['response']['docs'])

r409 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text409 = r409.text
json.loads(text409)
df409 = pd.json_normalize(r409.json()['response']['docs'])

r408 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text408 = r408.text
json.loads(text408)
df408 = pd.json_normalize(r408.json()['response']['docs'])

r407 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text407 = r407.text
json.loads(text407)
df407 = pd.json_normalize(r407.json()['response']['docs'])

r406 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text406 = r406.text
json.loads(text406)
df406 = pd.json_normalize(r406.json()['response']['docs'])

r405 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text405 = r405.text
json.loads(text405)
df405 = pd.json_normalize(r405.json()['response']['docs'])

r404 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text404 = r404.text
json.loads(text404)
df404 = pd.json_normalize(r404.json()['response']['docs'])

r403 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text403 = r403.text
json.loads(text403)
df403 = pd.json_normalize(r403.json()['response']['docs'])

r402 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text402 = r402.text
json.loads(text402)
df402 = pd.json_normalize(r402.json()['response']['docs'])

r401 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text401 = r401.text
json.loads(text401)
df401 = pd.json_normalize(r401.json()['response']['docs'])

r400 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text400 = r400.text
json.loads(text400)
df400 = pd.json_normalize(r400.json()['response']['docs'])

r499 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text499 = r499.text
json.loads(text499)
df499 = pd.json_normalize(r499.json()['response']['docs'])

r498 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text498 = r498.text
json.loads(text498)
df498 = pd.json_normalize(r498.json()['response']['docs'])

r497 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text497 = r497.text
json.loads(text497)
df497 = pd.json_normalize(r497.json()['response']['docs'])

r496 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text496 = r496.text
json.loads(text496)
df496 = pd.json_normalize(r496.json()['response']['docs'])

r495 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text495 = r495.text
json.loads(text495)
df495 = pd.json_normalize(r495.json()['response']['docs'])

r494 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text494 = r494.text
json.loads(text494)
df494 = pd.json_normalize(r494.json()['response']['docs'])

r493 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text493 = r493.text
json.loads(text493)
df493 = pd.json_normalize(r493.json()['response']['docs'])

r492 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text492 = r492.text
json.loads(text492)
df492 = pd.json_normalize(r492.json()['response']['docs'])

r491 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text491 = r491.text
json.loads(text491)
df491 = pd.json_normalize(r491.json()['response']['docs'])

r490 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text490 = r490.text
json.loads(text490)
df490 = pd.json_normalize(r490.json()['response']['docs'])

r489 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text489 = r489.text
json.loads(text489)
df489 = pd.json_normalize(r489.json()['response']['docs'])

r488 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text488 = r488.text
json.loads(text488)
df488 = pd.json_normalize(r488.json()['response']['docs'])

r487 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text487 = r487.text
json.loads(text487)
df487 = pd.json_normalize(r487.json()['response']['docs'])

r486 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text486 = r486.text
json.loads(text486)
df486 = pd.json_normalize(r486.json()['response']['docs'])

r485 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text485 = r485.text
json.loads(text485)
df485 = pd.json_normalize(r485.json()['response']['docs'])

r484 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text484 = r484.text
json.loads(text484)
df484 = pd.json_normalize(r484.json()['response']['docs'])

r483 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text483 = r483.text
json.loads(text483)
df483 = pd.json_normalize(r483.json()['response']['docs'])

r482 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text482 = r482.text
json.loads(text482)
df482 = pd.json_normalize(r482.json()['response']['docs'])

r481 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/4.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text481 = r481.text
json.loads(text481)
df481 = pd.json_normalize(r481.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
apr_concat = pd.concat([df421, df420, df419, df418, df417, df416, df415, df414, df413, df412, df411, 
                    df410, df409, df408, df407, df406, df405, df404, df403, df402, df401, 
                    df400, df499, df498, df497, df496, df495, df494, df493, df492, df491, 
                    df490, df489, df488, df487, df486, df485, df484, df483, df482, df481])

# %%
apr_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332586 entries, 0 to 7694
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 332586 non-null  object
#  1   web_url                  332586 non-null  object
#  2   snippet                  332586 non-null  object
#  3   lead_paragraph           332586 non-null  object
#  4   source                   332586 non-null  object
#  5   multimedia               332586 non-null  object
#  6   keywords                 332586 non-null  object
#  7   pub_date                 332586 non-null  object
#  8   document_type            332586 non-null  object
#  9   news_desk                332586 non-null  object
#  10  section_name             332586 non-null  object
#  11  subsection_name          48621 non-null   object
#  12  type_of_material         332586 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
apr_df = apr_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
apr_df
# Out:
#                                           headline.main  \
# 0     Nationals Player Tests Positive for Virus Befo...
# 1     Investment Firm’s Collapse Put Unseen Risks on...
# 2     Clerk Who Questioned $20 Bill Watched Floyd Ar...
# 3     40 Years After Reagan, a Bet Big Government Ca...
# 4     Investigators say a Trump aide took it upon hi...
# ...                                                 ...
# 7690  President of Somalia Expels 10 Of Ruling Counc...
# 7691  HARVARD GROUP VOTES A PLAN FOR MINORITIES FOR ...
# 7692                        Tool Orders Fall Below 1980
# 7693                              BYRNE MAKES DEGNAN AD
# 7694  ABC-TV WILL REPLACE 8 SHOWS IN 6 1/2 PRIME-TIM...
#
#                       pub_date  section_name  word_count  \
# 0     2021-04-01T00:11:14+0000        Sports         571
# 1     2021-04-01T00:16:27+0000  Business Day        1125
# 2     2021-04-01T00:20:17+0000          U.S.        1093
# 3     2021-04-01T00:22:17+0000          U.S.        1202
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
apr_df.to_csv('April 1981-2021.csv', index=False)
