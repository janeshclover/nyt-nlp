# %% [markdown]
# # NYT API Data Collection: November

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting November data 1981-2021:*

# %%
r1121 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1121 = r1121.text
json.loads(text1121)
df1121 = pd.json_normalize(r1121.json()['response']['docs'])

r1120 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1120 = r1120.text
json.loads(text1120)
df1120 = pd.json_normalize(r1120.json()['response']['docs'])

r1119 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1119 = r1119.text
json.loads(text1119)
df1119 = pd.json_normalize(r1119.json()['response']['docs'])

r1118 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1118 = r1118.text
json.loads(text1118)
df1118 = pd.json_normalize(r1118.json()['response']['docs'])

r1117 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1117 = r1117.text
json.loads(text1117)
df1117 = pd.json_normalize(r1117.json()['response']['docs'])

r1116 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1116 = r1116.text
json.loads(text1116)
df1116 = pd.json_normalize(r1116.json()['response']['docs'])

r1115 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1115 = r1115.text
json.loads(text1115)
df1115 = pd.json_normalize(r1115.json()['response']['docs'])

r1114 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1114 = r1114.text
json.loads(text1114)
df1114 = pd.json_normalize(r1114.json()['response']['docs'])

r1113 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1113 = r1113.text
json.loads(text1113)
df1113 = pd.json_normalize(r1113.json()['response']['docs'])

r1112 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1112 = r1112.text
json.loads(text1112)
df1112 = pd.json_normalize(r1112.json()['response']['docs'])

r1111 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1111 = r1111.text
json.loads(text1111)
df1111 = pd.json_normalize(r1111.json()['response']['docs'])

r1110 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1110 = r1110.text
json.loads(text1110)
df1110 = pd.json_normalize(r1110.json()['response']['docs'])

r1109 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1109 = r1109.text
json.loads(text1109)
df1109 = pd.json_normalize(r1109.json()['response']['docs'])

r1108 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1108 = r1108.text
json.loads(text1108)
df1108 = pd.json_normalize(r1108.json()['response']['docs'])

r1107 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1107 = r1107.text
json.loads(text1107)
df1107 = pd.json_normalize(r1107.json()['response']['docs'])

r1106 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1106 = r1106.text
json.loads(text1106)
df1106 = pd.json_normalize(r1106.json()['response']['docs'])

r1105 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1105 = r1105.text
json.loads(text1105)
df1105 = pd.json_normalize(r1105.json()['response']['docs'])

r1104 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1104 = r1104.text
json.loads(text1104)
df1104 = pd.json_normalize(r1104.json()['response']['docs'])

r1103 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1103 = r1103.text
json.loads(text1103)
df1103 = pd.json_normalize(r1103.json()['response']['docs'])

r1102 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1102 = r1102.text
json.loads(text1102)
df1102 = pd.json_normalize(r1102.json()['response']['docs'])

r1101 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1101 = r1101.text
json.loads(text1101)
df1101 = pd.json_normalize(r1101.json()['response']['docs'])

r1100 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1100 = r1100.text
json.loads(text1100)
df1100 = pd.json_normalize(r1100.json()['response']['docs'])

r1199 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1199 = r1199.text
json.loads(text1199)
df1199 = pd.json_normalize(r1199.json()['response']['docs'])

r1198 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1198 = r1198.text
json.loads(text1198)
df1198 = pd.json_normalize(r1198.json()['response']['docs'])

r1197 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1197 = r1197.text
json.loads(text1197)
df1197 = pd.json_normalize(r1197.json()['response']['docs'])

r1196 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1196 = r1196.text
json.loads(text1196)
df1196 = pd.json_normalize(r1196.json()['response']['docs'])

r1195 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1195 = r1195.text
json.loads(text1195)
df1195 = pd.json_normalize(r1195.json()['response']['docs'])

r1194 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1194 = r1194.text
json.loads(text1194)
df1194 = pd.json_normalize(r1194.json()['response']['docs'])

r1193 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1193 = r1193.text
json.loads(text1193)
df1193 = pd.json_normalize(r1193.json()['response']['docs'])

r1192 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1192 = r1192.text
json.loads(text1192)
df1192 = pd.json_normalize(r1192.json()['response']['docs'])

r1191 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1191 = r1191.text
json.loads(text1191)
df1191 = pd.json_normalize(r1191.json()['response']['docs'])

r1190 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1190 = r1190.text
json.loads(text1190)
df1190 = pd.json_normalize(r1190.json()['response']['docs'])

r1189 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1189 = r1189.text
json.loads(text1189)
df1189 = pd.json_normalize(r1189.json()['response']['docs'])

r1188 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1188 = r1188.text
json.loads(text1188)
df1188 = pd.json_normalize(r1188.json()['response']['docs'])

r1187 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1187 = r1187.text
json.loads(text1187)
df1187 = pd.json_normalize(r1187.json()['response']['docs'])

r1186 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1186 = r1186.text
json.loads(text1186)
df1186 = pd.json_normalize(r1186.json()['response']['docs'])

r1185 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1185 = r1185.text
json.loads(text1185)
df1185 = pd.json_normalize(r1185.json()['response']['docs'])

r1184 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1184 = r1184.text
json.loads(text1184)
df1184 = pd.json_normalize(r1184.json()['response']['docs'])

r1183 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1183 = r1183.text
json.loads(text1183)
df1183 = pd.json_normalize(r1183.json()['response']['docs'])

r1182 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1182 = r1182.text
json.loads(text1182)
df1182 = pd.json_normalize(r1182.json()['response']['docs'])

r1181 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/11.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1181 = r1181.text
json.loads(text1181)
df1181 = pd.json_normalize(r1181.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
nov_concat = pd.concat([df1121, df1120, df1119, df1118, df1117, df1116, df1115, df1114, df1113, df1112, df1111, 
                    df1110, df1109, df1108, df1107, df1106, df1105, df1104, df1103, df1102, df1101, 
                    df1100, df1199, df1198, df1197, df1196, df1195, df1194, df1193, df1192, df1191, 
                    df1190, df1189, df1188, df1187, df1186, df1185, df1184, df1183, df1182, df1181])

# %%
nov_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329694 entries, 0 to 8735
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 329694 non-null  object
#  1   web_url                  329694 non-null  object
#  2   snippet                  329694 non-null  object
#  3   lead_paragraph           329694 non-null  object
#  4   print_section            274009 non-null  object
#  5   print_page               273919 non-null  object
#  6   source                   329694 non-null  object
#  7   multimedia               329694 non-null  object
#  8   keywords                 329694 non-null  object
#  9   pub_date                 329694 non-null  object
#  10  document_type            329694 non-null  object
#  11  news_desk                329694 non-null  object
#  12  section_name             329694 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
nov_df = nov_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
nov_df
# Out:
#                                           headline.main  \
# 0     Why a Pilot Is Under Investigation for Saying ...
# 1     ‘Succession’ Season 3, Episode 3: Head Spaces ...
# 2                                  Your Monday Briefing
# 3     What Is a ‘Carbon Footprint’? And 12 Other Cli...
# 4     ‘Insecure’ Recap, Season 5, Episode 2: Pick Up...
# ...                                                 ...
# 8731                      THE INTERNATIONAL DRY CLEANER
# 8732            SABRES RALLY TO SET BACK ISLANDERS, 5-2
# 8733                 SYMPHONY: Y ORCHESTRA GOES BAROQUE
# 8734     JARUZELSKI WARNS POLAND ON ENDING LABOR UNREST
# 8735                                Gas Price Drop Seen
#
#                       pub_date  section_name  word_count  \
# 0     2021-11-01T00:06:56+0000          U.S.         477
# 1     2021-11-01T02:01:06+0000          Arts        1502
# 2     2021-11-01T02:13:41+0000      Briefing        1270
# 3     2021-11-01T02:28:31+0000       Climate           0
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
nov_df.to_csv('November 1981-2021.csv', index=False)

# %%
df_nov = pd.read_csv('November 1981-2021.csv')
# Out:
# /var/folders/zc/btqvdm252wdg_fy7vx1d1q0w0000gn/T/ipykernel_5234/3957044283.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nov = pd.read_csv('November 1981-2021.csv')

# %%
df_nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329696 entries, 0 to 329695
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   headline.main   329658 non-null  object
#  1   pub_date        329694 non-null  object
#  2   section_name    329594 non-null  object
#  3   word_count      329694 non-null  float64
#  4   lead_paragraph  318675 non-null  object
#  5   abstract        327143 non-null  object
#  6   snippet         186682 non-null  object
#  7   web_url         329694 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 20.1+ MB

# %%
df_nov.head()
# Out:
#                                        headline.main  \
# 0  Why a Pilot Is Under Investigation for Saying ...
# 1  ‘Succession’ Season 3, Episode 3: Head Spaces ...
# 2                               Your Monday Briefing
# 3  What Is a ‘Carbon Footprint’? And 12 Other Cli...
# 4  ‘Insecure’ Recap, Season 5, Episode 2: Pick Up...
#
#                    pub_date section_name  word_count  \
# 0  2021-11-01T00:06:56+0000         U.S.       477.0
# 1  2021-11-01T02:01:06+0000         Arts      1502.0
# 2  2021-11-01T02:13:41+0000     Briefing      1270.0
# 3  2021-11-01T02:28:31+0000      Climate         0.0
# 4  2021-11-01T02:31:03+0000         Arts      1009.0
#
#                                       lead_paragraph  \
# 0  It began as a chant at a NASCAR race. It becam...
# 1  (Check out a recap of the latest episode in Se...
# 2  Presidents and prime ministers are gathering i...
# 3  As climate change discussions take center stag...
# ...
