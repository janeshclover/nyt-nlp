# %% [markdown]
# # NYT API Data Collection: January

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting January data 1981-2021:*

# %%
r0121 = requests.get("https://api.nytimes.com/svc/archive/v1/2021/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm")
text0121 = r0121.text
json.loads(text0121)
df0121 = pd.json_normalize(r0121.json()['response']['docs'])

r0120 = requests.get("https://api.nytimes.com/svc/archive/v1/2020/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm")
text0120 = r0120.text
json.loads(text0120)
df0120 = pd.json_normalize(r0120.json()['response']['docs'])

r0119 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0119 = r0119.text
json.loads(text0119)
df0119 = pd.json_normalize(r0119.json()['response']['docs'])

r0118 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0118 = r0118.text
json.loads(text0118)
df0118 = pd.json_normalize(r0118.json()['response']['docs'])

r0117 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0117 = r0117.text
json.loads(text0117)
df0117 = pd.json_normalize(r0117.json()['response']['docs'])

r0116 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0116 = r0116.text
json.loads(text0116)
df0116 = pd.json_normalize(r0116.json()['response']['docs'])

r0115 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0115 = r0115.text
json.loads(text0115)
df0115 = pd.json_normalize(r0115.json()['response']['docs'])

r0114 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0114 = r0114.text
json.loads(text0114)
df0114 = pd.json_normalize(r0114.json()['response']['docs'])

r0113 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0113 = r0113.text
json.loads(text0113)
df0113 = pd.json_normalize(r0113.json()['response']['docs'])

r0112 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0112 = r0112.text
json.loads(text0112)
df0112 = pd.json_normalize(r0112.json()['response']['docs'])

r0111 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0111 = r0111.text
json.loads(text0111)
df0111 = pd.json_normalize(r0111.json()['response']['docs'])

r0110 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0110 = r0110.text
json.loads(text0110)
df0110 = pd.json_normalize(r0110.json()['response']['docs'])

r0109 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0109 = r0109.text
json.loads(text0109)
df0109 = pd.json_normalize(r0109.json()['response']['docs'])

r0108 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0108 = r0108.text
json.loads(text0108)
df0108 = pd.json_normalize(r0108.json()['response']['docs'])

r0107 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0107 = r0107.text
json.loads(text0107)
df0107 = pd.json_normalize(r0107.json()['response']['docs'])

r0106 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0106 = r0106.text
json.loads(text0106)
df0106 = pd.json_normalize(r0106.json()['response']['docs'])

r0105 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0105 = r0105.text
json.loads(text0105)
df0105 = pd.json_normalize(r0105.json()['response']['docs'])

r0104 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0104 = r0104.text
json.loads(text0104)
df0104 = pd.json_normalize(r0104.json()['response']['docs'])

r0103 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0103 = r0103.text
json.loads(text0103)
df0103 = pd.json_normalize(r0103.json()['response']['docs'])

r0102 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0102 = r0102.text
json.loads(text0102)
df0102 = pd.json_normalize(r0102.json()['response']['docs'])

r0101 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0101 = r0101.text
json.loads(text0101)
df0101 = pd.json_normalize(r0101.json()['response']['docs'])

r0100 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0100 = r0100.text
json.loads(text0100)
df0100 = pd.json_normalize(r0100.json()['response']['docs'])

r0199 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0199 = r0199.text
json.loads(text0199)
df0199 = pd.json_normalize(r0199.json()['response']['docs'])

r0198 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0198 = r0198.text
json.loads(text0198)
df0198 = pd.json_normalize(r0198.json()['response']['docs'])
r0197 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0197 = r0197.text
json.loads(text0197)
df0197 = pd.json_normalize(r0197.json()['response']['docs'])

r0196 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0196 = r0196.text
json.loads(text0196)
df0196 = pd.json_normalize(r0196.json()['response']['docs'])

r0195 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0195 = r0195.text
json.loads(text0195)
df0195 = pd.json_normalize(r0195.json()['response']['docs'])

r0194 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0194 = r0194.text
json.loads(text0194)
df0194 = pd.json_normalize(r0194.json()['response']['docs'])

r0193 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0193 = r0193.text
json.loads(text0193)
df0193 = pd.json_normalize(r0193.json()['response']['docs'])

r0192 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0192 = r0192.text
json.loads(text0192)
df0192 = pd.json_normalize(r0192.json()['response']['docs'])

r0191 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0191 = r0191.text
json.loads(text0191)
df0191 = pd.json_normalize(r0191.json()['response']['docs'])

r0190 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0190 = r0190.text
json.loads(text0190)
df0190 = pd.json_normalize(r0190.json()['response']['docs'])

r0189 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0189 = r0189.text
json.loads(text0189)
df0189 = pd.json_normalize(r0189.json()['response']['docs'])

r0188 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0188 = r0188.text
json.loads(text0188)
df0188 = pd.json_normalize(r0188.json()['response']['docs'])

r0187 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0187 = r0187.text
json.loads(text0187)
df0187 = pd.json_normalize(r0187.json()['response']['docs'])

r0186 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0186 = r0186.text
json.loads(text0186)
df0186 = pd.json_normalize(r0186.json()['response']['docs'])

r0185 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0185 = r0185.text
json.loads(text0185)
df0185 = pd.json_normalize(r0185.json()['response']['docs'])

r0184 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0184 = r0184.text
json.loads(text0184)
df0184 = pd.json_normalize(r0184.json()['response']['docs'])

r0183 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0183 = r0183.text
json.loads(text0183)
df0183 = pd.json_normalize(r0183.json()['response']['docs'])

r0182 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0182 = r0182.text
json.loads(text0182)
df0182 = pd.json_normalize(r0182.json()['response']['docs'])

r0181 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/1.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text0181 = r0181.text
json.loads(text0181)
df0181 = pd.json_normalize(r0181.json()['response']['docs'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 203>()
#     201 text0181 = r0181.text
#     202 json.loads(text0181)
# --> 203 df0181 = pd.json_normalize(r0181.json()['response']['docs'])
#
# KeyError: 'response'

# %% [markdown]
# *Concatenating individual months/years:*

# %%
jan_concat = pd.concat([df0121, df0120, df0119, df0118, df0117, df0116, df0115, df0114, df0113, df0112, 
                        df0111, df0110, df0109, df0108, df0107, df0106, df0105, df0104, df0103, df0102, 
                        df0101, df0100, df0199, df0198, df0197, df0196, df0195, df0194, df0193, df0192, 
                        df0191, df0190, df0189, df0188, df0187, df0186, df0185, df0184, df0183, df0182, df0181])

# %%
jan_concat.info()

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
jan_df = jan_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
jan_df

# %% [markdown]
# *Pushing data to csv:*

# %%
jan_df.to_csv('January 1981-2021.csv', index=False)
