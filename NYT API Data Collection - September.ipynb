# %% [markdown]
# # NYT API Data Collection: September

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting September data 1981-2021:*

# %%
r921 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text921 = r921.text
json.loads(text921)
df921 = pd.json_normalize(r921.json()['response']['docs'])

r920 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text920 = r920.text
json.loads(text920)
df920 = pd.json_normalize(r920.json()['response']['docs'])

r919 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text919 = r919.text
json.loads(text919)
df919 = pd.json_normalize(r919.json()['response']['docs'])

r918 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text918 = r918.text
json.loads(text918)
df918 = pd.json_normalize(r918.json()['response']['docs'])

r917 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text917 = r917.text
json.loads(text917)
df917 = pd.json_normalize(r917.json()['response']['docs'])

r916 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text916 = r916.text
json.loads(text916)
df916 = pd.json_normalize(r916.json()['response']['docs'])

r915 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text915 = r915.text
json.loads(text915)
df915 = pd.json_normalize(r915.json()['response']['docs'])

r914 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text914 = r914.text
json.loads(text914)
df914 = pd.json_normalize(r914.json()['response']['docs'])

r913 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text913 = r913.text
json.loads(text913)
df913 = pd.json_normalize(r913.json()['response']['docs'])

r912 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text912 = r912.text
json.loads(text912)
df912 = pd.json_normalize(r912.json()['response']['docs'])

r911 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text911 = r911.text
json.loads(text911)
df911 = pd.json_normalize(r911.json()['response']['docs'])

r910 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text910 = r910.text
json.loads(text910)
df910 = pd.json_normalize(r910.json()['response']['docs'])

r909 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text909 = r909.text
json.loads(text909)
df909 = pd.json_normalize(r909.json()['response']['docs'])

r908 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text908 = r908.text
json.loads(text908)
df908 = pd.json_normalize(r908.json()['response']['docs'])

r907 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text907 = r907.text
json.loads(text907)
df907 = pd.json_normalize(r907.json()['response']['docs'])

r906 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text906 = r906.text
json.loads(text906)
df906 = pd.json_normalize(r906.json()['response']['docs'])

r905 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text905 = r905.text
json.loads(text905)
df905 = pd.json_normalize(r905.json()['response']['docs'])

r904 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text904 = r904.text
json.loads(text904)
df904 = pd.json_normalize(r904.json()['response']['docs'])

r903 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text903 = r903.text
json.loads(text903)
df903 = pd.json_normalize(r903.json()['response']['docs'])

r902 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text902 = r902.text
json.loads(text902)
df902 = pd.json_normalize(r902.json()['response']['docs'])

r901 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text901 = r901.text
json.loads(text901)
df901 = pd.json_normalize(r901.json()['response']['docs'])

r900 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text900 = r900.text
json.loads(text900)
df900 = pd.json_normalize(r900.json()['response']['docs'])

r999 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text999 = r999.text
json.loads(text999)
df999 = pd.json_normalize(r999.json()['response']['docs'])

r998 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text998 = r998.text
json.loads(text998)
df998 = pd.json_normalize(r998.json()['response']['docs'])

r997 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text997 = r997.text
json.loads(text997)
df997 = pd.json_normalize(r997.json()['response']['docs'])

r996 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text996 = r996.text
json.loads(text996)
df996 = pd.json_normalize(r996.json()['response']['docs'])

r995 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text995 = r995.text
json.loads(text995)
df995 = pd.json_normalize(r995.json()['response']['docs'])

r994 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text994 = r994.text
json.loads(text994)
df994 = pd.json_normalize(r994.json()['response']['docs'])

r993 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text993 = r993.text
json.loads(text993)
df993 = pd.json_normalize(r993.json()['response']['docs'])

r992 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text992 = r992.text
json.loads(text992)
df992 = pd.json_normalize(r992.json()['response']['docs'])

r991 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text991 = r991.text
json.loads(text991)
df991 = pd.json_normalize(r991.json()['response']['docs'])

r990 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text990 = r990.text
json.loads(text990)
df990 = pd.json_normalize(r990.json()['response']['docs'])

r989 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text989 = r989.text
json.loads(text989)
df989 = pd.json_normalize(r989.json()['response']['docs'])

r988 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text988 = r988.text
json.loads(text988)
df988 = pd.json_normalize(r988.json()['response']['docs'])

r987 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text987 = r987.text
json.loads(text987)
df987 = pd.json_normalize(r987.json()['response']['docs'])

r986 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text986 = r986.text
json.loads(text986)
df986 = pd.json_normalize(r986.json()['response']['docs'])

r985 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text985 = r985.text
json.loads(text985)
df985 = pd.json_normalize(r985.json()['response']['docs'])

r984 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text984 = r984.text
json.loads(text984)
df984 = pd.json_normalize(r984.json()['response']['docs'])

r983 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text983 = r983.text
json.loads(text983)
df983 = pd.json_normalize(r983.json()['response']['docs'])

r982 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text982 = r982.text
json.loads(text982)
df982 = pd.json_normalize(r982.json()['response']['docs'])

r981 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/9.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text981 = r981.text
json.loads(text981)
df981 = pd.json_normalize(r981.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
sep_concat = pd.concat([df921, df920, df919, df918, df917, df916, df915, df914, df913, df912, df911, 
                    df910, df909, df908, df907, df906, df905, df904, df903, df902, df901, 
                    df900, df999, df998, df997, df996, df995, df994, df993, df992, df991, 
                    df990, df989, df988, df987, df986, df985, df984, df983, df982, df981])

# %%
sep_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325397 entries, 0 to 7311
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 325397 non-null  object
#  1   web_url                  325397 non-null  object
#  2   snippet                  325397 non-null  object
#  3   lead_paragraph           325397 non-null  object
#  4   print_section            259939 non-null  object
#  5   print_page               259884 non-null  object
#  6   source                   325397 non-null  object
#  7   multimedia               325397 non-null  object
#  8   keywords                 325397 non-null  object
#  9   pub_date                 325397 non-null  object
#  10  document_type            325397 non-null  object
#  11  news_desk                325397 non-null  object
#  12  section_name             325397 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
sep_df = sep_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
sep_df
# Out:
#                                           headline.main  \
# 0     Biden Defends Afghan Pullout and Declares an E...
# 1                 An Afghan Left Behind Tells His Story
# 2     What Is Stefanos Tsitsipas Doing in the Bathro...
# 3     Goalball Teammates Set Paralympic Record for L...
# 4     Developer Charged in Scheme to Bilk Matt Gaetz...
# ...                                                 ...
# 7307                       WEDNESDAY SEPTEMBER 30, 1981
# 7308                              V OSNE-ROMANEE,France
# 7309       A DEBT OF $1 TRILLION: ITS EFFECT ON ECONOMY
# 7310                         Southeast Drought Persists
# 7311  ARCATA BACKS $330 MILLION BID FOR ACQUISITION ...
#
#                       pub_date   section_name  word_count  \
# 0     2021-09-01T00:13:59+0000           U.S.        1487
# 1     2021-09-01T00:24:18+0000        Opinion         453
# 2     2021-09-01T00:28:01+0000         Sports        1172
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
sep_df.to_csv('September 1981-2021.csv', index=False)
