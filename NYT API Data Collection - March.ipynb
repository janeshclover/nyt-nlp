# %% [markdown]
# # NYT API Data Collection: March

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting March data 1981-2021:*

# %%
r321 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text321 = r321.text
json.loads(text321)
df321 = pd.json_normalize(r321.json()['response']['docs'])

r320 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text320 = r320.text
json.loads(text320)
df320 = pd.json_normalize(r320.json()['response']['docs'])

r319 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text319 = r319.text
json.loads(text319)
df319 = pd.json_normalize(r319.json()['response']['docs'])

r318 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text318 = r318.text
json.loads(text318)
df318 = pd.json_normalize(r318.json()['response']['docs'])

r317 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text317 = r317.text
json.loads(text317)
df317 = pd.json_normalize(r317.json()['response']['docs'])

r316 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text316 = r316.text
json.loads(text316)
df316 = pd.json_normalize(r316.json()['response']['docs'])

r315 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text315 = r315.text
json.loads(text315)
df315 = pd.json_normalize(r315.json()['response']['docs'])

r314 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text314 = r314.text
json.loads(text314)
df314 = pd.json_normalize(r314.json()['response']['docs'])

r313 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text313 = r313.text
json.loads(text313)
df313 = pd.json_normalize(r313.json()['response']['docs'])

r312 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text312 = r312.text
json.loads(text312)
df312 = pd.json_normalize(r312.json()['response']['docs'])

r311 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text311 = r311.text
json.loads(text311)
df311 = pd.json_normalize(r311.json()['response']['docs'])

r310 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text310 = r310.text
json.loads(text310)
df310 = pd.json_normalize(r310.json()['response']['docs'])

r309 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text309 = r309.text
json.loads(text309)
df309 = pd.json_normalize(r309.json()['response']['docs'])

r308 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text308 = r308.text
json.loads(text308)
df308 = pd.json_normalize(r308.json()['response']['docs'])

r307 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text307 = r307.text
json.loads(text307)
df307 = pd.json_normalize(r307.json()['response']['docs'])

r306 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text306 = r306.text
json.loads(text306)
df306 = pd.json_normalize(r306.json()['response']['docs'])

r305 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text305 = r305.text
json.loads(text305)
df305 = pd.json_normalize(r305.json()['response']['docs'])

r304 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text304 = r304.text
json.loads(text304)
df304 = pd.json_normalize(r304.json()['response']['docs'])

r303 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text303 = r303.text
json.loads(text303)
df303 = pd.json_normalize(r303.json()['response']['docs'])

r302 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text302 = r302.text
json.loads(text302)
df302 = pd.json_normalize(r302.json()['response']['docs'])

r301 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text301 = r301.text
json.loads(text301)
df301 = pd.json_normalize(r301.json()['response']['docs'])

r300 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text300 = r300.text
json.loads(text300)
df300 = pd.json_normalize(r300.json()['response']['docs'])

r399 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text399 = r399.text
json.loads(text399)
df399 = pd.json_normalize(r399.json()['response']['docs'])

r398 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text398 = r398.text
json.loads(text398)
df398 = pd.json_normalize(r398.json()['response']['docs'])

r397 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text397 = r397.text
json.loads(text397)
df397 = pd.json_normalize(r397.json()['response']['docs'])

r396 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text396 = r396.text
json.loads(text396)
df396 = pd.json_normalize(r396.json()['response']['docs'])

r395 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text395 = r395.text
json.loads(text395)
df395 = pd.json_normalize(r395.json()['response']['docs'])

r394 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text394 = r394.text
json.loads(text394)
df394 = pd.json_normalize(r394.json()['response']['docs'])

r393 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text393 = r393.text
json.loads(text393)
df393 = pd.json_normalize(r393.json()['response']['docs'])

r392 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text392 = r392.text
json.loads(text392)
df392 = pd.json_normalize(r392.json()['response']['docs'])

r391 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text391 = r391.text
json.loads(text391)
df391 = pd.json_normalize(r391.json()['response']['docs'])

r390 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text390 = r390.text
json.loads(text390)
df390 = pd.json_normalize(r390.json()['response']['docs'])

r389 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text389 = r389.text
json.loads(text389)
df389 = pd.json_normalize(r389.json()['response']['docs'])

r388 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text388 = r388.text
json.loads(text388)
df388 = pd.json_normalize(r388.json()['response']['docs'])

r387 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text387 = r387.text
json.loads(text387)
df387 = pd.json_normalize(r387.json()['response']['docs'])

r386 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text386 = r386.text
json.loads(text386)
df386 = pd.json_normalize(r386.json()['response']['docs'])

r385 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text385 = r385.text
json.loads(text385)
df385 = pd.json_normalize(r385.json()['response']['docs'])

r384 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text384 = r384.text
json.loads(text384)
df384 = pd.json_normalize(r384.json()['response']['docs'])

r383 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text383 = r383.text
json.loads(text383)
df383 = pd.json_normalize(r383.json()['response']['docs'])

r382 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text382 = r382.text
json.loads(text382)
df382 = pd.json_normalize(r382.json()['response']['docs'])

r381 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/3.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text381 = r381.text
json.loads(text381)
df381 = pd.json_normalize(r381.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
mar_concat = pd.concat([df321, df320, df319, df318, df317, df316, df315, df314, df313, df312, df311, 
                    df310, df309, df308, df307, df306, df305, df304, df303, df302, df301, 
                    df300, df399, df398, df397, df396, df395, df394, df393, df392, df391, 
                    df390, df389, df388, df387, df386, df385, df384, df383, df382, df381])

# %%
mar_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 331883 entries, 0 to 7686
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 331883 non-null  object
#  1   web_url                  331883 non-null  object
#  2   snippet                  331883 non-null  object
#  3   lead_paragraph           331883 non-null  object
#  4   source                   331883 non-null  object
#  5   multimedia               331883 non-null  object
#  6   keywords                 331883 non-null  object
#  7   pub_date                 331883 non-null  object
#  8   document_type            331883 non-null  object
#  9   news_desk                331883 non-null  object
#  10  section_name             331883 non-null  object
#  11  type_of_material         331883 non-null  object
#  12  _id                      331883 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
mar_df = mar_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
mar_df
# Out:
#                                           headline.main  \
# 0      How to watch the Golden Globes on TV and Online.
# 1      What will win tonight? Here are our predictions.
# 2     Daniel Kaluuya and Chadwick Boseman are both r...
# 3     Full Text of Cuomo’s Statement in Response to ...
# 4     Forget ‘Succession.’ You Can Watch ‘90 Day Fia...
# ...                                                 ...
# 7682               Company Is Fined For Trade With Iran
# 7683                               GUATEMALA AND BELIZE
# 7684       By Sports of The Times; The NBC Championship
# 7685  WILLIAMS JURY IS SELECTED IN BROOKLYN ABSCAM CASE
# 7686  ONE ACQUITTAL ORDERED AT GOODY MUSIC TRIAL OVE...
#
#                       pub_date  section_name  word_count  \
# 0     2021-03-01T00:01:56+0000        Movies         120
# 1     2021-03-01T00:01:57+0000        Movies         268
# 2     2021-03-01T00:02:02+0000        Movies         408
# 3     2021-03-01T00:07:43+0000      New York         279
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
mar_df.to_csv('March 1981-2021.csv', index=False)
