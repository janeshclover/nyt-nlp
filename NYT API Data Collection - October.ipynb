# %% [markdown]
# # NYT API Data Collection: October

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting October data 1981-2021:*

# %%
r1021 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1021 = r1021.text
json.loads(text1021)
df1021 = pd.json_normalize(r1021.json()['response']['docs'])

r1020 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1020 = r1020.text
json.loads(text1020)
df1020 = pd.json_normalize(r1020.json()['response']['docs'])

r1019 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1019 = r1019.text
json.loads(text1019)
df1019 = pd.json_normalize(r1019.json()['response']['docs'])

r1018 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1018 = r1018.text
json.loads(text1018)
df1018 = pd.json_normalize(r1018.json()['response']['docs'])

r1017 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1017 = r1017.text
json.loads(text1017)
df1017 = pd.json_normalize(r1017.json()['response']['docs'])

r1016 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1016 = r1016.text
json.loads(text1016)
df1016 = pd.json_normalize(r1016.json()['response']['docs'])

r1015 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1015 = r1015.text
json.loads(text1015)
df1015 = pd.json_normalize(r1015.json()['response']['docs'])

r1014 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1014 = r1014.text
json.loads(text1014)
df1014 = pd.json_normalize(r1014.json()['response']['docs'])

r1013 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1013 = r1013.text
json.loads(text1013)
df1013 = pd.json_normalize(r1013.json()['response']['docs'])

r1012 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1012 = r1012.text
json.loads(text1012)
df1012 = pd.json_normalize(r1012.json()['response']['docs'])

r1011 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1011 = r1011.text
json.loads(text1011)
df1011 = pd.json_normalize(r1011.json()['response']['docs'])

r1010 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1010 = r1010.text
json.loads(text1010)
df1010 = pd.json_normalize(r1010.json()['response']['docs'])

r1009 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1009 = r1009.text
json.loads(text1009)
df1009 = pd.json_normalize(r1009.json()['response']['docs'])

r1008 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1008 = r1008.text
json.loads(text1008)
df1008 = pd.json_normalize(r1008.json()['response']['docs'])

r1007 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1007 = r1007.text
json.loads(text1007)
df1007 = pd.json_normalize(r1007.json()['response']['docs'])

r1006 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1006 = r1006.text
json.loads(text1006)
df1006 = pd.json_normalize(r1006.json()['response']['docs'])

r1005 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1005 = r1005.text
json.loads(text1005)
df1005 = pd.json_normalize(r1005.json()['response']['docs'])

r1004 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1004 = r1004.text
json.loads(text1004)
df1004 = pd.json_normalize(r1004.json()['response']['docs'])

r1003 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1003 = r1003.text
json.loads(text1003)
df1003 = pd.json_normalize(r1003.json()['response']['docs'])

r1002 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1002 = r1002.text
json.loads(text1002)
df1002 = pd.json_normalize(r1002.json()['response']['docs'])

r1001 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1001 = r1001.text
json.loads(text1001)
df1001 = pd.json_normalize(r1001.json()['response']['docs'])

r1000 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1000 = r1000.text
json.loads(text1000)
df1000 = pd.json_normalize(r1000.json()['response']['docs'])

# %%
r1099 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1099 = r1099.text
json.loads(text1099)
df1099 = pd.json_normalize(r1099.json()['response']['docs'])

r1098 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1098 = r1098.text
json.loads(text1098)
df1098 = pd.json_normalize(r1098.json()['response']['docs'])

r1097 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1097 = r1097.text
json.loads(text1097)
df1097 = pd.json_normalize(r1097.json()['response']['docs'])

r1096 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1096 = r1096.text
json.loads(text1096)
df1096 = pd.json_normalize(r1096.json()['response']['docs'])

r1095 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1095 = r1095.text
json.loads(text1095)
df1095 = pd.json_normalize(r1095.json()['response']['docs'])

r1094 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1094 = r1094.text
json.loads(text1094)
df1094 = pd.json_normalize(r1094.json()['response']['docs'])

r1093 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1093 = r1093.text
json.loads(text1093)
df1093 = pd.json_normalize(r1093.json()['response']['docs'])

r1092 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1092 = r1092.text
json.loads(text1092)
df1092 = pd.json_normalize(r1092.json()['response']['docs'])

r1091 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1091 = r1091.text
json.loads(text1091)
df1091 = pd.json_normalize(r1091.json()['response']['docs'])

r1090 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1090 = r1090.text
json.loads(text1090)
df1090 = pd.json_normalize(r1090.json()['response']['docs'])

r1089 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1089 = r1089.text
json.loads(text1089)
df1089 = pd.json_normalize(r1089.json()['response']['docs'])

r1088 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1088 = r1088.text
json.loads(text1088)
df1088 = pd.json_normalize(r1088.json()['response']['docs'])

r1087 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1087 = r1087.text
json.loads(text1087)
df1087 = pd.json_normalize(r1087.json()['response']['docs'])

r1086 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1086 = r1086.text
json.loads(text1086)
df1086 = pd.json_normalize(r1086.json()['response']['docs'])

r1085 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1085 = r1085.text
json.loads(text1085)
df1085 = pd.json_normalize(r1085.json()['response']['docs'])

r1084 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1084 = r1084.text
json.loads(text1084)
df1084 = pd.json_normalize(r1084.json()['response']['docs'])

r1083 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1083 = r1083.text
json.loads(text1083)
df1083 = pd.json_normalize(r1083.json()['response']['docs'])

r1082 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1082 = r1082.text
json.loads(text1082)
df1082 = pd.json_normalize(r1082.json()['response']['docs'])

r1081 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/10.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1081 = r1081.text
json.loads(text1081)
df1081 = pd.json_normalize(r1081.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
oct_concat = pd.concat([df1021, df1020, df1019, df1018, df1017, df1016, df1015, df1014, df1013, df1012, df1011, 
                    df1010, df1009, df1008, df1007, df1006, df1005, df1004, df1003, df1002, df1001, 
                    df1000, df1099, df1098, df1097, df1096, df1095, df1094, df1093, df1092, df1091, 
                    df1090, df1089, df1088, df1087, df1086, df1085, df1084, df1083, df1082, df1081])

# %%
oct_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359594 entries, 0 to 9166
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 359594 non-null  object
#  1   web_url                  359594 non-null  object
#  2   snippet                  359594 non-null  object
#  3   lead_paragraph           359594 non-null  object
#  4   print_section            291776 non-null  object
#  5   print_page               291691 non-null  object
#  6   source                   359594 non-null  object
#  7   multimedia               359594 non-null  object
#  8   keywords                 359594 non-null  object
#  9   pub_date                 359594 non-null  object
#  10  document_type            359594 non-null  object
#  11  news_desk                359594 non-null  object
#  12  section_name             359594 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
oct_df = oct_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
oct_df
# Out:
#                                           headline.main  \
# 0            When the Doctor’s Notes Hurt Your Feelings
# 1     House Delays Vote on Infrastructure Bill as De...
# 2     Tirzah’s Genre-Less Pop Embraces the Beauty of...
# 3     Senate Confirms Biden’s Pick to Lead the Burea...
# 4     UMass Amherst Hires Cybersecurity Firm to Inve...
# ...                                                 ...
# 9162  BLUE CHIP STAMPS CO reports earnings for Qtr t...
# 9163  VALMAC INDUSTRIES INC reports earnings for Qtr...
# 9164  Around the World; North Korea Says U.S.  Is Vi...
# 9165         NEW-HOME SALES DOWN 12.6%, TO A RECORD LOW
# 9166  A $5 BILLION OFFER FOR MARATHON OIL IS MADE BY...
#
#                       pub_date  section_name  word_count  \
# 0     2021-10-01T00:05:08+0000          Well        1203
# 1     2021-10-01T00:05:58+0000          U.S.        1561
# 2     2021-10-01T00:08:13+0000          Arts         546
# 3     2021-10-01T00:22:35+0000       Climate         641
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
oct_df.to_csv('October 1981-2021.csv', index=False)
