# %% [markdown]
# # NYT API Data Collection: December

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# *Collecting December data 1981-2021:*

# %%
r1221 = requests.get('https://api.nytimes.com/svc/archive/v1/2021/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1221 = r1221.text
json.loads(text1221)
df1221 = pd.json_normalize(r1221.json()['response']['docs'])

r1220 = requests.get('https://api.nytimes.com/svc/archive/v1/2020/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1220 = r1220.text
json.loads(text1220)
df1220 = pd.json_normalize(r1220.json()['response']['docs'])

r1219 = requests.get('https://api.nytimes.com/svc/archive/v1/2019/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1219 = r1219.text
json.loads(text1219)
df1219 = pd.json_normalize(r1219.json()['response']['docs'])

r1218 = requests.get('https://api.nytimes.com/svc/archive/v1/2018/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1218 = r1218.text
json.loads(text1218)
df1218 = pd.json_normalize(r1218.json()['response']['docs'])

r1217 = requests.get('https://api.nytimes.com/svc/archive/v1/2017/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1217 = r1217.text
json.loads(text1217)
df1217 = pd.json_normalize(r1217.json()['response']['docs'])

r1216 = requests.get('https://api.nytimes.com/svc/archive/v1/2016/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1216 = r1216.text
json.loads(text1216)
df1216 = pd.json_normalize(r1216.json()['response']['docs'])

r1215 = requests.get('https://api.nytimes.com/svc/archive/v1/2015/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1215 = r1215.text
json.loads(text1215)
df1215 = pd.json_normalize(r1215.json()['response']['docs'])

r1214 = requests.get('https://api.nytimes.com/svc/archive/v1/2014/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1214 = r1214.text
json.loads(text1214)
df1214 = pd.json_normalize(r1214.json()['response']['docs'])

r1213 = requests.get('https://api.nytimes.com/svc/archive/v1/2013/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1213 = r1213.text
json.loads(text1213)
df1213 = pd.json_normalize(r1213.json()['response']['docs'])

r1212 = requests.get('https://api.nytimes.com/svc/archive/v1/2012/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1212 = r1212.text
json.loads(text1212)
df1212 = pd.json_normalize(r1212.json()['response']['docs'])

r1211 = requests.get('https://api.nytimes.com/svc/archive/v1/2011/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1211 = r1211.text
json.loads(text1211)
df1211 = pd.json_normalize(r1211.json()['response']['docs'])

r1210 = requests.get('https://api.nytimes.com/svc/archive/v1/2010/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1210 = r1210.text
json.loads(text1210)
df1210 = pd.json_normalize(r1210.json()['response']['docs'])

r1209 = requests.get('https://api.nytimes.com/svc/archive/v1/2009/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1209 = r1209.text
json.loads(text1209)
df1209 = pd.json_normalize(r1209.json()['response']['docs'])

r1208 = requests.get('https://api.nytimes.com/svc/archive/v1/2008/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1208 = r1208.text
json.loads(text1208)
df1208 = pd.json_normalize(r1208.json()['response']['docs'])

r1207 = requests.get('https://api.nytimes.com/svc/archive/v1/2007/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1207 = r1207.text
json.loads(text1207)
df1207 = pd.json_normalize(r1207.json()['response']['docs'])

r1206 = requests.get('https://api.nytimes.com/svc/archive/v1/2006/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1206 = r1206.text
json.loads(text1206)
df1206 = pd.json_normalize(r1206.json()['response']['docs'])

r1205 = requests.get('https://api.nytimes.com/svc/archive/v1/2005/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1205 = r1205.text
json.loads(text1205)
df1205 = pd.json_normalize(r1205.json()['response']['docs'])

r1204 = requests.get('https://api.nytimes.com/svc/archive/v1/2004/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1204 = r1204.text
json.loads(text1204)
df1204 = pd.json_normalize(r1204.json()['response']['docs'])

r1203 = requests.get('https://api.nytimes.com/svc/archive/v1/2003/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1203 = r1203.text
json.loads(text1203)
df1203 = pd.json_normalize(r1203.json()['response']['docs'])

r1202 = requests.get('https://api.nytimes.com/svc/archive/v1/2002/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1202 = r1202.text
json.loads(text1202)
df1202 = pd.json_normalize(r1202.json()['response']['docs'])

r1201 = requests.get('https://api.nytimes.com/svc/archive/v1/2001/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1201 = r1201.text
json.loads(text1201)
df1201 = pd.json_normalize(r1201.json()['response']['docs'])

r1200 = requests.get('https://api.nytimes.com/svc/archive/v1/2000/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1200 = r1200.text
json.loads(text1200)
df1200 = pd.json_normalize(r1200.json()['response']['docs'])

r1299 = requests.get('https://api.nytimes.com/svc/archive/v1/1999/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1299 = r1299.text
json.loads(text1299)
df1299 = pd.json_normalize(r1299.json()['response']['docs'])

r1298 = requests.get('https://api.nytimes.com/svc/archive/v1/1998/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1298 = r1298.text
json.loads(text1298)
df1298 = pd.json_normalize(r1298.json()['response']['docs'])

r1297 = requests.get('https://api.nytimes.com/svc/archive/v1/1997/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1297 = r1297.text
json.loads(text1297)
df1297 = pd.json_normalize(r1297.json()['response']['docs'])

r1296 = requests.get('https://api.nytimes.com/svc/archive/v1/1996/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1296 = r1296.text
json.loads(text1296)
df1296 = pd.json_normalize(r1296.json()['response']['docs'])

r1295 = requests.get('https://api.nytimes.com/svc/archive/v1/1995/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1295 = r1295.text
json.loads(text1295)
df1295 = pd.json_normalize(r1295.json()['response']['docs'])

r1294 = requests.get('https://api.nytimes.com/svc/archive/v1/1994/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1294 = r1294.text
json.loads(text1294)
df1294 = pd.json_normalize(r1294.json()['response']['docs'])

r1293 = requests.get('https://api.nytimes.com/svc/archive/v1/1993/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1293 = r1293.text
json.loads(text1293)
df1293 = pd.json_normalize(r1293.json()['response']['docs'])

r1292 = requests.get('https://api.nytimes.com/svc/archive/v1/1992/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1292 = r1292.text
json.loads(text1292)
df1292 = pd.json_normalize(r1292.json()['response']['docs'])

r1291 = requests.get('https://api.nytimes.com/svc/archive/v1/1991/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1291 = r1291.text
json.loads(text1291)
df1291 = pd.json_normalize(r1291.json()['response']['docs'])

r1290 = requests.get('https://api.nytimes.com/svc/archive/v1/1990/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1290 = r1290.text
json.loads(text1290)
df1290 = pd.json_normalize(r1290.json()['response']['docs'])

r1289 = requests.get('https://api.nytimes.com/svc/archive/v1/1989/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1289 = r1289.text
json.loads(text1289)
df1289 = pd.json_normalize(r1289.json()['response']['docs'])

r1288 = requests.get('https://api.nytimes.com/svc/archive/v1/1988/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1288 = r1288.text
json.loads(text1288)
df1288 = pd.json_normalize(r1288.json()['response']['docs'])

r1287 = requests.get('https://api.nytimes.com/svc/archive/v1/1987/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1287 = r1287.text
json.loads(text1287)
df1287 = pd.json_normalize(r1287.json()['response']['docs'])

r1286 = requests.get('https://api.nytimes.com/svc/archive/v1/1986/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1286 = r1286.text
json.loads(text1286)
df1286 = pd.json_normalize(r1286.json()['response']['docs'])

r1285 = requests.get('https://api.nytimes.com/svc/archive/v1/1985/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1285 = r1285.text
json.loads(text1285)
df1285 = pd.json_normalize(r1285.json()['response']['docs'])

r1284 = requests.get('https://api.nytimes.com/svc/archive/v1/1984/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1284 = r1284.text
json.loads(text1284)
df1284 = pd.json_normalize(r1284.json()['response']['docs'])

r1283 = requests.get('https://api.nytimes.com/svc/archive/v1/1983/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1283 = r1283.text
json.loads(text1283)
df1283 = pd.json_normalize(r1283.json()['response']['docs'])

r1282 = requests.get('https://api.nytimes.com/svc/archive/v1/1982/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1282 = r1282.text
json.loads(text1282)
df1282 = pd.json_normalize(r1282.json()['response']['docs'])

r1281 = requests.get('https://api.nytimes.com/svc/archive/v1/1981/12.json?api-key=00HlzA3JMLbrrvLVRil1MjJtG90tvNYm')
text1281 = r1281.text
json.loads(text1281)
df1281 = pd.json_normalize(r1281.json()['response']['docs'])

# %% [markdown]
# *Concatenating individual months/years:*

# %%
dec_concat = pd.concat([df1221, df1220, df1219, df1218, df1217, df1216, df1215, df1214, df1213, df1212, df1211, 
                    df1210, df1209, df1208, df1207, df1206, df1205, df1204, df1203, df1202, df1201, 
                    df1200, df1299, df1298, df1297, df1296, df1295, df1294, df1293, df1292, df1291, 
                    df1290, df1289, df1288, df1287, df1286, df1285, df1284, df1283, df1282, df1281])

# %%
dec_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 312344 entries, 0 to 8006
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   abstract                 312344 non-null  object
#  1   web_url                  312344 non-null  object
#  2   snippet                  312344 non-null  object
#  3   lead_paragraph           312344 non-null  object
#  4   print_section            259440 non-null  object
#  5   print_page               259352 non-null  object
#  6   source                   312344 non-null  object
#  7   multimedia               312344 non-null  object
#  8   keywords                 312344 non-null  object
#  9   pub_date                 312344 non-null  object
#  10  document_type            312344 non-null  object
#  11  news_desk                312344 non-null  object
#  12  section_name             312344 non-null  object
# ...

# %% [markdown]
# *Cleaning df to only needed values:*

# %%
dec_df = dec_concat[['headline.main','pub_date','section_name','word_count','lead_paragraph','abstract','snippet','web_url']]

# %%
dec_df
# Out:
#                                           headline.main  \
# 0                       Let’s End the Covid Blame Games
# 1     Trump’s Iran Policy Has Become a Disaster for ...
# 2     This Extinct Eagle May Have Gulped Guts Like a...
# 3     Republican Recriminations Point to a Rocky Pat...
# 4     A Times editor who attended Oxford recalls a d...
# ...                                                 ...
# 8002       AT MODERN, LUMET'S LOVE AFFAIR WITH NEW YORK
# 8003                                          Key Rates
# 8004              ART: PHOTOS OF ARTISTS BY HANS NAMUTH
# 8005                         NOVEMBER NEW-HOME SALES UP
# 8006   A COUNCIL PANEL OFFERS NEW PLAN ON REDISTRICTING
#
#                       pub_date  section_name  word_count  \
# 0     2021-12-01T00:00:07+0000       Opinion         918
# 1     2021-12-01T00:00:07+0000       Opinion        1560
# 2     2021-12-01T00:00:10+0000       Science         913
# 3     2021-12-01T00:14:33+0000          U.S.        1172
# ...

# %% [markdown]
# *Pushing data to csv:*

# %%
dec_df.to_csv('December 1981-2021.csv', index=False)
